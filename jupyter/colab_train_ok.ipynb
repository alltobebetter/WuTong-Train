# %% [markdown]
# # 梧桐杯 AI 安全告警智能研判系统 - Colab 训练
#
# ## 📋 训练流程
#
# 1. ✅ 克隆 GitHub 仓库
# 2. ✅ 安装依赖
# 3. ✅ 检查数据
# 4. ✅ 数据预处理
# 5. ✅ 训练 V2 模型（XGBoost + CatBoost + LightGBM）
# 6. ✅ 查看训练结果
# 7. ✅ 下载模型文件
#
# ## ⚙️ 运行前准备
#
# 1. 确保运行时类型设置为 **GPU**（Runtime > Change runtime type > GPU）
# 2. 按顺序执行每个单元格
# 3. 训练时间约 10-15 分钟
#
# ---

# %%
# 1. 克隆 GitHub 仓库
# !git clone https://github.com/alltobebetter/WuTong.git
# %cd WuTong

# 查看项目结构
# !ls -la
# Out:
# Cloning into 'WuTong'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 74 (delta 14), reused 74 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 1.56 MiB | 13.65 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/WuTong
# total 104
# drwxr-xr-x 8 root root  4096 Feb 14 14:23 .
# drwxr-xr-x 1 root root  4096 Feb 14 14:23 ..
# -rw-r--r-- 1 root root  2481 Feb 14 14:23 CHANGELOG.md
# -rw-r--r-- 1 root root  4266 Feb 14 14:23 COLAB_GUIDE.md
# -rw-r--r-- 1 root root 13448 Feb 14 14:23 colab_train.ipynb
# drwxr-xr-x 4 root root  4096 Feb 14 14:23 data
# drwxr-xr-x 8 root root  4096 Feb 14 14:23 .git
# -rw-r--r-- 1 root root   244 Feb 14 14:23 .gitignore
# drwxr-xr-x 2 root root  4096 Feb 14 14:23 legacy
# drwxr-xr-x 2 root root  4096 Feb 14 14:23 models
# -rw-r--r-- 1 root root  4689 Feb 14 14:23 PROJECT_PLAN.txt
# -rw-r--r-- 1 root root  3003 Feb 14 14:23 QUICK_START.md
# -rw-r--r-- 1 root root  3429 Feb 14 14:23 race_topic_clean.txt
# -rw-r--r-- 1 root root  4454 Feb 14 14:23 README.md
# -rw-r--r-- 1 root root   416 Feb 14 14:23 requirements-colab.txt
# -rw-r--r-- 1 root root   340 Feb 14 14:23 requirements.txt
# drwxr-xr-x 2 root root  4096 Feb 14 14:23 scripts
# drwxr-xr-x 5 root root  4096 Feb 14 14:23 src
# -rw-r--r-- 1 root root  4740 Feb 14 14:23 SUMMARY.md

# %%
# 2. 安装依赖
print("📦 安装依赖包...")
# !pip install -q -r requirements-colab.txt

print("\n✅ 依赖安装完成！")

# 验证关键包
import xgboost as xgb
import catboost as cb
import lightgbm as lgb
import pandas as pd

print(f"XGBoost 版本: {xgb.__version__}")
print(f"CatBoost 版本: {cb.__version__}")
print(f"LightGBM 版本: {lgb.__version__}")
print(f"Pandas 版本: {pd.__version__}")
# Out:
# 📦 安装依赖包...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 10.6 MB/s eta 0:00:00
#
# ✅ 依赖安装完成！
# XGBoost 版本: 3.1.3
# CatBoost 版本: 1.2.8
# LightGBM 版本: 4.6.0
# Pandas 版本: 2.2.2

# %%
# 3. 检查 GPU 可用性
import torch

if torch.cuda.is_available():
    print(f"✅ GPU 可用: {torch.cuda.get_device_name(0)}")
    print(f"   显存: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
else:
    print("⚠️ GPU 不可用，将使用 CPU 训练（速度较慢）")
    print("   建议: Runtime > Change runtime type > GPU")
# Out:
# ✅ GPU 可用: Tesla T4
#    显存: 14.56 GB

# %%
# 4. 检查数据集
import pandas as pd
from pathlib import Path

# 查找数据文件
data_files = list(Path('data').rglob('*.xlsx'))
print(f"找到 {len(data_files)} 个数据文件:")
for f in data_files:
    print(f"  - {f}")

if data_files:
    # 读取第一个数据文件
    df = pd.read_excel(data_files[0])
    print(f"\n数据集大小: {len(df)} 条")
    print(f"\n列名: {df.columns.tolist()}")
    print(f"\n攻击类型分布:")
    print(df.iloc[:, -1].value_counts())
else:
    print("\n⚠️ 未找到数据文件！")
    print("请确保 data/ 目录下有数据文件")
# Out:
# 找到 2 个数据文件:
#   - data/原始告警信息样例数据集V1.2.xlsx
#   - data/raw/原始告警信息样例数据集V1.2.xlsx
#
# 数据集大小: 11000 条
#
# 列名: ['timestamp', 'user_agent', 'method', 'src_ip', 'dst_ip', 'url_path', 'request_body', 'attack_type(结果列，需参赛选手判断输出)']
#
# 攻击类型分布:
# attack_type(结果列，需参赛选手判断输出)
# 正常访问              3413
# 目录遍历攻击             972
# 远程命令执行攻击           965
# SQL注入攻击            964
# 文件包含攻击             959
# XSS跨站脚本攻击          958
# CSRF攻击             942
# Java反序列化漏洞利用攻击     920
# 文件上传攻击             907
# Name: count, dtype: int64

# %%
# 5. 数据预处理
print("🔄 开始数据预处理...")

# 查找 Excel 文件
import glob
excel_files = glob.glob('data/**/*.xlsx', recursive=True)

if excel_files:
    data_file = excel_files[0]
    print(f"使用数据文件: {data_file}")

    # 运行预处理
    # !python scripts/ingest.py "{data_file}"

    print("\n✅ 数据预处理完成！")

    # 检查生成的 parquet 文件
    parquet_files = glob.glob('data/staging/*.parquet')
    print(f"\n生成的 parquet 文件: {parquet_files}")
else:
    print("❌ 未找到 Excel 数据文件！")
# Out:
# 🔄 开始数据预处理...
# 使用数据文件: data/原始告警信息样例数据集V1.2.xlsx
# 2026-02-14 14:24:01,353 INFO 读取 原始告警信息样例数据集V1.2.xlsx 成功，形状: (11000, 8)
# 2026-02-14 14:24:01,456 INFO 已保存标准化数据: /content/WuTong/data/staging/原始告警信息样例数据集V1.2.parquet  (11000 条)
# ✔ 已生成: /content/WuTong/data/staging/原始告警信息样例数据集V1.2.parquet
#
# ✅ 数据预处理完成！
#
# 生成的 parquet 文件: ['data/staging/原始告警信息样例数据集V1.2.parquet']

# %%
# 6. 训练 V2 模型（完整训练，带交叉验证）
print("🚀 开始训练 V2 模型...")
print("模型: XGBoost + CatBoost + LightGBM")
print("交叉验证: 5 折")
print("预计时间: 10-15 分钟\n")

# !python scripts/train_v2.py --version v2.0.0

print("\n✅ 训练完成！")
# Out:
# 🚀 开始训练 V2 模型...
# 模型: XGBoost + CatBoost + LightGBM
# 交叉验证: 5 折
# 预计时间: 10-15 分钟
#
# 使用数据: /content/WuTong/data/staging/原始告警信息样例数据集V1.2.parquet
# 模型版本: v2.0.0
# 交叉验证: 是 (5 折)
# 2026-02-14 14:24:08,078 INFO === 训练开始 V2: version=v2.0.0 ===
# 2026-02-14 14:24:08,101 INFO 数据加载: 11000 条
# 2026-02-14 14:24:08,103 INFO 攻击类型分布:
# attack_type
# 正常访问              3413
# 目录遍历攻击             972
# 远程命令执行攻击           965
# SQL注入攻击            964
# 文件包含攻击             959
# XSS跨站脚本攻击          958
# CSRF攻击             942
# Java反序列化漏洞利用攻击     920
# 文件上传攻击             907
# Name: count, dtype: int64
# 2026-02-14 14:24:08,104 INFO 特征提取 ...
# 2026-02-14 14:24:08,104 INFO 开始特征提取，共 11000 条记录 ...
# 2026-02-14 14:24:08,540 INFO   特征提取进度: 2000 / 11000
# 2026-02-14 14:24:09,114 INFO   特征提取进度: 4000 / 11000
# 2026-02-14 14:24:09,854 INFO   特征提取进度: 6000 / 11000
# 2026-02-14 14:24:10,626 INFO   特征提取进度: 8000 / 11000
# 2026-02-14 14:24:11,242 INFO   特征提取进度: 10000 / 11000
# 2026-02-14 14:24:11,545 INFO 特征提取完成，新增 26 个特征列
# 2026-02-14 14:24:11,551 INFO 训练告警聚合器 ...
# 2026-02-14 14:24:11,551 INFO 开始告警聚合（训练模式），共 11000 条 ...
# 2026-02-14 14:24:12,502 INFO TF-IDF 特征维度: (11000, 1000)
# 2026-02-14 14:24:14,869 INFO 聚类数: 29, 噪声点: 56
# 2026-02-14 14:24:14,873 INFO AlertAggregator 已保存: /content/WuTong/models/v2.0.0/aggregator.pkl
# 2026-02-14 14:24:14,880 INFO 特征数量: 25
# 2026-02-14 14:24:14,880 INFO
# === 多分类训练 ===
# 2026-02-14 14:24:14,889 INFO --- 训练 XGBoost ---
# 2026-02-14 14:24:16,576 INFO   Fold 1: 0.9710
# 2026-02-14 14:24:17,842 INFO   Fold 2: 0.9693
# 2026-02-14 14:24:19,119 INFO   Fold 3: 0.9670
# 2026-02-14 14:24:20,997 INFO   Fold 4: 0.9688
# 2026-02-14 14:24:23,791 INFO   Fold 5: 0.9790
# 2026-02-14 14:24:23,791 INFO   平均 CV 准确率: 0.9710 (±0.0042)
# 2026-02-14 14:24:25,350 INFO   测试集准确率: 0.9768
# 2026-02-14 14:24:25,350 INFO   测试集 F1: 0.9768
# 2026-02-14 14:24:25,351 INFO --- 训练 CatBoost ---
# 2026-02-14 14:24:30,236 INFO   Fold 1: 0.9665
# 2026-02-14 14:24:36,204 INFO   Fold 2: 0.9670
# 2026-02-14 14:24:41,072 INFO   Fold 3: 0.9682
# 2026-02-14 14:24:46,365 INFO   Fold 4: 0.9659
# 2026-02-14 14:24:51,758 INFO   Fold 5: 0.9773
# 2026-02-14 14:24:51,759 INFO   平均 CV 准确率: 0.9690 (±0.0042)
# 2026-02-14 14:24:57,358 INFO   测试集准确率: 0.9750
# 2026-02-14 14:24:57,358 INFO   测试集 F1: 0.9751
# 2026-02-14 14:24:57,358 INFO --- 训练 LightGBM ---
# 2026-02-14 14:24:59,982 INFO   Fold 1: 0.9693
# 2026-02-14 14:25:01,214 INFO   Fold 2: 0.9670
# 2026-02-14 14:25:02,478 INFO   Fold 3: 0.9676
# 2026-02-14 14:25:03,703 INFO   Fold 4: 0.9699
# 2026-02-14 14:25:04,962 INFO   Fold 5: 0.9790
# 2026-02-14 14:25:04,962 INFO   平均 CV 准确率: 0.9706 (±0.0043)
# 2026-02-14 14:25:06,454 INFO   测试集准确率: 0.9750
# 2026-02-14 14:25:06,454 INFO   测试集 F1: 0.9750
# 2026-02-14 14:25:06,455 INFO
# === 集成模型训练 ===
# 2026-02-14 14:25:16,031 INFO 集成模型准确率: 0.9759
# 2026-02-14 14:25:16,031 INFO 集成模型 F1: 0.9760
# 2026-02-14 14:25:16,039 INFO 分类报告:
#                 precision    recall  f1-score   support
#
#         CSRF攻击     0.8974    0.9309    0.9138       188
# Java反序列化漏洞利用攻击     1.0000    1.0000    1.0000       184
#        SQL注入攻击     0.9787    0.9534    0.9659       193
#      XSS跨站脚本攻击     1.0000    0.9896    0.9948       192
#         文件上传攻击     0.9945    1.0000    0.9972       181
#         文件包含攻击     0.9784    0.9427    0.9602       192
#           正常访问     0.9666    0.9751    0.9708       683
#         目录遍历攻击     0.9948    0.9948    0.9948       194
#       远程命令执行攻击     1.0000    1.0000    1.0000       193
#
#       accuracy                         0.9759      2200
#      macro avg     0.9789    0.9763    0.9775      2200
#   weighted avg     0.9762    0.9759    0.9760      2200
#
# 2026-02-14 14:25:16,041 INFO 混淆矩阵:
# [[175   0   0   0   0   1  12   0   0]
#  [  0 184   0   0   0   0   0   0   0]
#  [  0   0 184   0   1   0   8   0   0]
#  [  0   0   0 190   0   0   2   0   0]
#  [  0   0   0   0 181   0   0   0   0]
#  [  8   0   1   0   0 181   1   1   0]
#  [ 12   0   3   0   0   2 666   0   0]
#  [  0   0   0   0   0   1   0 193   0]
#  [  0   0   0   0   0   0   0   0 193]]
# 2026-02-14 14:25:16,494 INFO === 训练完成，模型已保存: /content/WuTong/models/v2.0.0 ===
# 2026-02-14 14:25:16,494 INFO 文件列表: ['aggregator.pkl', 'catboost.pkl', 'ensemble.pkl', 'lightgbm.pkl', 'feature_list.json', 'label_encoder.pkl', 'manifest.json', 'classification_report.txt', 'xgboost.pkl']
#
# ✔ 模型已保存: /content/WuTong/models/v2.0.0
# ✔ 查看结果: /content/WuTong/models/v2.0.0/manifest.json
#
# ✅ 训练完成！

# %%
# 6-alternative. 快速训练（不带交叉验证，约 5 分钟）
# 如果想快速测试，可以运行这个单元格代替上面的单元格

# print("⚡ 快速训练模式（不带交叉验证）...")
# !python scripts/train_v2.py --version v2.0.0-fast --no-cv
# print("\n✅ 快速训练完成！")

# %%
# 7. 查看训练结果
import json
from pathlib import Path

manifest_path = Path('models/v2.0.0/manifest.json')

if manifest_path.exists():
    with open(manifest_path, 'r', encoding='utf-8') as f:
        manifest = json.load(f)

    print("=" * 60)
    print("📊 训练结果")
    print("=" * 60)
    print(f"\n版本: {manifest['version']}")
    print(f"训练时间: {manifest['trained_at']}")
    print(f"数据量: {manifest['data_rows']} 条")
    print(f"特征数: {len(manifest['feature_list'])} 个")
    print(f"类别数: {len(manifest['classes'])} 类")

    print("\n" + "=" * 60)
    print("🎯 模型性能")
    print("=" * 60)

    metrics = manifest['metrics']

    # 单模型性能
    for model_name in ['xgboost', 'catboost', 'lightgbm']:
        if model_name in metrics:
            m = metrics[model_name]
            print(f"\n{model_name.upper()}:")
            print(f"  测试准确率: {m['test_accuracy']:.4f}")
            print(f"  测试 F1: {m['test_f1']:.4f}")
            if m.get('cv_accuracy'):
                print(f"  交叉验证准确率: {m['cv_accuracy']:.4f}")

    # 集成模型性能
    if 'ensemble' in metrics:
        e = metrics['ensemble']
        print(f"\n{'='*60}")
        print(f"🏆 集成模型（最终模型）")
        print(f"{'='*60}")
        print(f"  准确率: {e['test_accuracy']:.4f} ({e['test_accuracy']*100:.2f}%)")
        print(f"  F1 分数: {e['test_f1']:.4f}")

    print("\n" + "=" * 60)

    # 读取详细分类报告
    report_path = Path('models/v2.0.0/classification_report.txt')
    if report_path.exists():
        print("\n📋 详细分类报告:")
        print("=" * 60)
        with open(report_path, 'r', encoding='utf-8') as f:
            print(f.read())
else:
    print("❌ 未找到训练结果文件！")
    print("请先运行训练单元格")
# Out:
# ============================================================
# 📊 训练结果
# ============================================================
#
# 版本: v2.0.0
# 训练时间: 2026-02-14T14:25:16.493378+00:00
# 数据量: 11000 条
# 特征数: 25 个
# 类别数: 9 类
#
# ============================================================
# 🎯 模型性能
# ============================================================
#
# XGBOOST:
#   测试准确率: 0.9768
#   测试 F1: 0.9768
#   交叉验证准确率: 0.9710
#
# CATBOOST:
#   测试准确率: 0.9750
#   测试 F1: 0.9751
#   交叉验证准确率: 0.9690
#
# LIGHTGBM:
#   测试准确率: 0.9750
#   测试 F1: 0.9750
#   交叉验证准确率: 0.9706
#
# ============================================================
# 🏆 集成模型（最终模型）
# ============================================================
#   准确率: 0.9759 (97.59%)
#   F1 分数: 0.9760
#
# ============================================================
#
# 📋 详细分类报告:
# ============================================================
#                 precision    recall  f1-score   support
#
#         CSRF攻击     0.8974    0.9309    0.9138       188
# Java反序列化漏洞利用攻击     1.0000    1.0000    1.0000       184
#        SQL注入攻击     0.9787    0.9534    0.9659       193
#      XSS跨站脚本攻击     1.0000    0.9896    0.9948       192
#         文件上传攻击     0.9945    1.0000    0.9972       181
#         文件包含攻击     0.9784    0.9427    0.9602       192
#           正常访问     0.9666    0.9751    0.9708       683
#         目录遍历攻击     0.9948    0.9948    0.9948       194
#       远程命令执行攻击     1.0000    1.0000    1.0000       193
#
#       accuracy                         0.9759      2200
#      macro avg     0.9789    0.9763    0.9775      2200
#   weighted avg     0.9762    0.9759    0.9760      2200

# %%
# 8. 对比不同版本模型（如果有 V1 模型）
# !python scripts/compare_models.py
# Out:
# 找到 1 个模型版本: v2.0.0
#
# +-------------+---------------------+----------+-------------+----------+----------+
# | 版本        | 训练时间            | 数据量   | 模型类型    |   准确率 |   F1分数 |
# +=============+=====================+==========+=============+==========+==========+
# | v2.0.0      | 2026-02-14T14:25:16 | 11000    | XGB+Cat+LGB |   0.9759 |   0.976  |
# +-------------+---------------------+----------+-------------+----------+----------+
# | └─ XGBoost  |                     |          |             |   0.9768 |   0.9768 |
# +-------------+---------------------+----------+-------------+----------+----------+
# | └─ CatBoost |                     |          |             |   0.975  |   0.9751 |
# +-------------+---------------------+----------+-------------+----------+----------+
# | └─ LightGBM |                     |          |             |   0.975  |   0.975  |
# +-------------+---------------------+----------+-------------+----------+----------+
#
# === 详细信息 ===
#
# 【v2.0.0】
#   训练时间: 2026-02-14T14:25:16.493378+00:00
#   数据量: 11000 条
#   特征数: 25 个
#   类别数: 9 类
#   交叉验证: True
#   CV折数: 5

# %%
# 9. 打包模型文件准备下载
print("📦 打包模型文件...")

# !zip -r models_v2.0.0.zip models/v2.0.0/

print("\n✅ 打包完成！")
print("\n文件大小:")
# !ls -lh models_v2.0.0.zip
# Out:
# 📦 打包模型文件...
#   adding: models/v2.0.0/ (stored 0%)
#   adding: models/v2.0.0/aggregator.pkl (deflated 73%)
#   adding: models/v2.0.0/catboost.pkl (deflated 78%)
#   adding: models/v2.0.0/ensemble.pkl (deflated 73%)
#   adding: models/v2.0.0/lightgbm.pkl (deflated 65%)
#   adding: models/v2.0.0/feature_list.json (deflated 59%)
#   adding: models/v2.0.0/label_encoder.pkl (deflated 16%)
#   adding: models/v2.0.0/manifest.json (deflated 54%)
#   adding: models/v2.0.0/classification_report.txt (deflated 55%)
#   adding: models/v2.0.0/xgboost.pkl (deflated 76%)
#
# ✅ 打包完成！
#
# 文件大小:
# -rw-r--r-- 1 root root 7.4M Feb 14 14:25 models_v2.0.0.zip

# %%
# 10. 下载模型文件到本地
from google.colab import files

print("⬇️ 开始下载模型文件...")
print("（下载完成后解压到本地项目的 models/ 目录）\n")

files.download('models_v2.0.0.zip')

print("\n✅ 下载完成！")
print("\n📝 后续步骤:")
print("1. 解压 models_v2.0.0.zip")
print("2. 将 models/v2.0.0/ 目录复制到本地项目")
print("3. 运行推理: python scripts/infer.py data/xxx.xlsx --model-version v2.0.0")
# Out:
# ⬇️ 开始下载模型文件...
# （下载完成后解压到本地项目的 models/ 目录）
# ✅ 下载完成！
#
# 📝 后续步骤:
# 1. 解压 models_v2.0.0.zip
# 2. 将 models/v2.0.0/ 目录复制到本地项目
# 3. 运行推理: python scripts/infer.py data/xxx.xlsx --model-version v2.0.0

# %%
# 11. 测试推理（可选）
import glob

excel_files = glob.glob('data/**/*.xlsx', recursive=True)
if excel_files:
    test_file = excel_files[0]
    print(f"🧪 测试推理: {test_file}")

    # !python scripts/infer.py "{test_file}" --model-version v2.0.0 --job-id colab_test

    print("\n✅ 推理完成！")
    print("\n查看结果:")
    # !ls -la data/outputs/colab_test/
else:
    print("❌ 未找到测试数据文件")
# Out:
# 🧪 测试推理: data/原始告警信息样例数据集V1.2.xlsx
# 2026-02-14 14:25:20,786 INFO === 推理任务开始: colab_test ===
# 2026-02-14 14:25:20,786 INFO [1/6] 数据导入标准化 ...
# 2026-02-14 14:25:21,973 INFO 读取 原始告警信息样例数据集V1.2.xlsx 成功，形状: (11000, 8)
# 2026-02-14 14:25:22,064 INFO 已保存标准化数据: /content/WuTong/data/staging/原始告警信息样例数据集V1.2.parquet  (11000 条)
# 2026-02-14 14:25:22,094 INFO 加载数据: 11000 条, 8 列
# 2026-02-14 14:25:22,094 INFO [2/6] 特征提取 ...
# 2026-02-14 14:25:22,094 INFO 开始特征提取，共 11000 条记录 ...
# 2026-02-14 14:25:22,811 INFO   特征提取进度: 2000 / 11000
# 2026-02-14 14:25:23,565 INFO   特征提取进度: 4000 / 11000
# 2026-02-14 14:25:23,995 INFO   特征提取进度: 6000 / 11000
# 2026-02-14 14:25:24,432 INFO   特征提取进度: 8000 / 11000
# 2026-02-14 14:25:24,939 INFO   特征提取进度: 10000 / 11000
# 2026-02-14 14:25:25,237 INFO 特征提取完成，新增 26 个特征列
# 2026-02-14 14:25:25,242 INFO [3/6] 告警降噪 ...
# 2026-02-14 14:25:25,243 INFO AlertAggregator 已加载: /content/WuTong/models/v2.0.0/aggregator.pkl
# 2026-02-14 14:25:25,243 INFO 开始告警聚合（推理模式），共 11000 条 ...
# 2026-02-14 14:25:28,257 INFO 推理聚类数: 29
# 2026-02-14 14:25:28,260 INFO 降噪率: 99.2%
# 2026-02-14 14:25:28,260 INFO [4/6] 攻击分类 ...
# 2026-02-14 14:25:30,062 INFO 已加载模型: /content/WuTong/models/v2.0.0/ensemble.pkl
# 2026-02-14 14:25:30,063 INFO 已加载标签编码器: /content/WuTong/models/v2.0.0/label_encoder.pkl
# 2026-02-14 14:25:30,063 INFO 模型版本: v2.0.0, 训练时间: 2026-02-14T14:25:16.493378+00:00
# 2026-02-14 14:25:31,141 INFO 分类预测完成，预测分布:
# 正常访问              3450
# 目录遍历攻击             971
# 远程命令执行攻击           966
# CSRF攻击             954
# XSS跨站脚本攻击          952
# 文件包含攻击             943
# SQL注入攻击            936
# Java反序列化漏洞利用攻击     920
# 文件上传攻击             908
# 2026-02-14 14:25:31,142 INFO [5/6] 风险评分 ...
# 2026-02-14 14:25:31,142 INFO 开始计算风险评分 ...
# 2026-02-14 14:25:32,013 INFO 风险等级分布:
# risk_level
# 低危    4128
# 信息    3939
# 中危    2933
# 2026-02-14 14:25:32,015 INFO [6/6] 报告生成 ...
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 24635 (\N{CJK UNIFIED IDEOGRAPH-603B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21578 (\N{CJK UNIFIED IDEOGRAPH-544A}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 35686 (\N{CJK UNIFIED IDEOGRAPH-8B66}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20005 (\N{CJK UNIFIED IDEOGRAPH-4E25}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21361 (\N{CJK UNIFIED IDEOGRAPH-5371}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 31181 (\N{CJK UNIFIED IDEOGRAPH-79CD}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20987 (\N{CJK UNIFIED IDEOGRAPH-51FB}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 31867 (\N{CJK UNIFIED IDEOGRAPH-7C7B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 22411 (\N{CJK UNIFIED IDEOGRAPH-578B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 22343 (\N{CJK UNIFIED IDEOGRAPH-5747}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 39118 (\N{CJK UNIFIED IDEOGRAPH-98CE}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 38505 (\N{CJK UNIFIED IDEOGRAPH-9669}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21344 (\N{CJK UNIFIED IDEOGRAPH-5360}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 27491 (\N{CJK UNIFIED IDEOGRAPH-6B63}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 24120 (\N{CJK UNIFIED IDEOGRAPH-5E38}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 35775 (\N{CJK UNIFIED IDEOGRAPH-8BBF}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 38382 (\N{CJK UNIFIED IDEOGRAPH-95EE}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 24405 (\N{CJK UNIFIED IDEOGRAPH-5F55}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 36941 (\N{CJK UNIFIED IDEOGRAPH-904D}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21382 (\N{CJK UNIFIED IDEOGRAPH-5386}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 36828 (\N{CJK UNIFIED IDEOGRAPH-8FDC}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21629 (\N{CJK UNIFIED IDEOGRAPH-547D}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20196 (\N{CJK UNIFIED IDEOGRAPH-4EE4}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 25191 (\N{CJK UNIFIED IDEOGRAPH-6267}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 36328 (\N{CJK UNIFIED IDEOGRAPH-8DE8}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 31449 (\N{CJK UNIFIED IDEOGRAPH-7AD9}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 33050 (\N{CJK UNIFIED IDEOGRAPH-811A}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21253 (\N{CJK UNIFIED IDEOGRAPH-5305}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21547 (\N{CJK UNIFIED IDEOGRAPH-542B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 27880 (\N{CJK UNIFIED IDEOGRAPH-6CE8}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20837 (\N{CJK UNIFIED IDEOGRAPH-5165}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21453 (\N{CJK UNIFIED IDEOGRAPH-53CD}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 24207 (\N{CJK UNIFIED IDEOGRAPH-5E8F}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21015 (\N{CJK UNIFIED IDEOGRAPH-5217}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 28431 (\N{CJK UNIFIED IDEOGRAPH-6F0F}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 27934 (\N{CJK UNIFIED IDEOGRAPH-6D1E}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21033 (\N{CJK UNIFIED IDEOGRAPH-5229}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 29992 (\N{CJK UNIFIED IDEOGRAPH-7528}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20256 (\N{CJK UNIFIED IDEOGRAPH-4F20}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 31561 (\N{CJK UNIFIED IDEOGRAPH-7B49}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 32423 (\N{CJK UNIFIED IDEOGRAPH-7EA7}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20013 (\N{CJK UNIFIED IDEOGRAPH-4E2D}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20302 (\N{CJK UNIFIED IDEOGRAPH-4F4E}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 24687 (\N{CJK UNIFIED IDEOGRAPH-606F}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 38408 (\N{CJK UNIFIED IDEOGRAPH-9608}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 23567 (\N{CJK UNIFIED IDEOGRAPH-5C0F}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 36235 (\N{CJK UNIFIED IDEOGRAPH-8D8B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21183 (\N{CJK UNIFIED IDEOGRAPH-52BF}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 35831 (\N{CJK UNIFIED IDEOGRAPH-8BF7}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 27714 (\N{CJK UNIFIED IDEOGRAPH-6C42}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 26041 (\N{CJK UNIFIED IDEOGRAPH-65B9}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 27861 (\N{CJK UNIFIED IDEOGRAPH-6CD5}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 28304 (\N{CJK UNIFIED IDEOGRAPH-6E90}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 23433 (\N{CJK UNIFIED IDEOGRAPH-5B89}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 20840 (\N{CJK UNIFIED IDEOGRAPH-5168}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 26234 (\N{CJK UNIFIED IDEOGRAPH-667A}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 33021 (\N{CJK UNIFIED IDEOGRAPH-80FD}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 30740 (\N{CJK UNIFIED IDEOGRAPH-7814}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 21028 (\N{CJK UNIFIED IDEOGRAPH-5224}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 31995 (\N{CJK UNIFIED IDEOGRAPH-7CFB}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 32479 (\N{CJK UNIFIED IDEOGRAPH-7EDF}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 24577 (\N{CJK UNIFIED IDEOGRAPH-6001}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# /content/WuTong/src/wutong/report.py:140: UserWarning: Glyph 23631 (\N{CJK UNIFIED IDEOGRAPH-5C4F}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight", facecolor="white")
# 2026-02-14 14:25:33,255 INFO 安全态势大屏已保存: /content/WuTong/data/outputs/colab_test/security_dashboard.png
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 39118 (\N{CJK UNIFIED IDEOGRAPH-98CE}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 38505 (\N{CJK UNIFIED IDEOGRAPH-9669}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20987 (\N{CJK UNIFIED IDEOGRAPH-51FB}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 31867 (\N{CJK UNIFIED IDEOGRAPH-7C7B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 22411 (\N{CJK UNIFIED IDEOGRAPH-578B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 27491 (\N{CJK UNIFIED IDEOGRAPH-6B63}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 24120 (\N{CJK UNIFIED IDEOGRAPH-5E38}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 35775 (\N{CJK UNIFIED IDEOGRAPH-8BBF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 38382 (\N{CJK UNIFIED IDEOGRAPH-95EE}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 24405 (\N{CJK UNIFIED IDEOGRAPH-5F55}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 36941 (\N{CJK UNIFIED IDEOGRAPH-904D}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21382 (\N{CJK UNIFIED IDEOGRAPH-5386}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 36328 (\N{CJK UNIFIED IDEOGRAPH-8DE8}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 31449 (\N{CJK UNIFIED IDEOGRAPH-7AD9}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 33050 (\N{CJK UNIFIED IDEOGRAPH-811A}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21453 (\N{CJK UNIFIED IDEOGRAPH-53CD}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 24207 (\N{CJK UNIFIED IDEOGRAPH-5E8F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21015 (\N{CJK UNIFIED IDEOGRAPH-5217}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 28431 (\N{CJK UNIFIED IDEOGRAPH-6F0F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 27934 (\N{CJK UNIFIED IDEOGRAPH-6D1E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21033 (\N{CJK UNIFIED IDEOGRAPH-5229}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 29992 (\N{CJK UNIFIED IDEOGRAPH-7528}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 27880 (\N{CJK UNIFIED IDEOGRAPH-6CE8}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20837 (\N{CJK UNIFIED IDEOGRAPH-5165}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21253 (\N{CJK UNIFIED IDEOGRAPH-5305}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21547 (\N{CJK UNIFIED IDEOGRAPH-542B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 36828 (\N{CJK UNIFIED IDEOGRAPH-8FDC}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21629 (\N{CJK UNIFIED IDEOGRAPH-547D}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20196 (\N{CJK UNIFIED IDEOGRAPH-4EE4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 25191 (\N{CJK UNIFIED IDEOGRAPH-6267}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20256 (\N{CJK UNIFIED IDEOGRAPH-4F20}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 26041 (\N{CJK UNIFIED IDEOGRAPH-65B9}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 27861 (\N{CJK UNIFIED IDEOGRAPH-6CD5}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21578 (\N{CJK UNIFIED IDEOGRAPH-544A}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 35686 (\N{CJK UNIFIED IDEOGRAPH-8B66}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 35814 (\N{CJK UNIFIED IDEOGRAPH-8BE6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 32454 (\N{CJK UNIFIED IDEOGRAPH-7EC6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 23567 (\N{CJK UNIFIED IDEOGRAPH-5C0F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 21608 (\N{CJK UNIFIED IDEOGRAPH-5468}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 20108 (\N{CJK UNIFIED IDEOGRAPH-4E8C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 19977 (\N{CJK UNIFIED IDEOGRAPH-4E09}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 22235 (\N{CJK UNIFIED IDEOGRAPH-56DB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 20116 (\N{CJK UNIFIED IDEOGRAPH-4E94}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 20845 (\N{CJK UNIFIED IDEOGRAPH-516D}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 26143 (\N{CJK UNIFIED IDEOGRAPH-661F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 21578 (\N{CJK UNIFIED IDEOGRAPH-544A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 35686 (\N{CJK UNIFIED IDEOGRAPH-8B66}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 21305 (\N{CJK UNIFIED IDEOGRAPH-5339}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 37197 (\N{CJK UNIFIED IDEOGRAPH-914D}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 20987 (\N{CJK UNIFIED IDEOGRAPH-51FB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 27169 (\N{CJK UNIFIED IDEOGRAPH-6A21}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 24335 (\N{CJK UNIFIED IDEOGRAPH-5F0F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 32479 (\N{CJK UNIFIED IDEOGRAPH-7EDF}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:195: UserWarning: Glyph 35745 (\N{CJK UNIFIED IDEOGRAPH-8BA1}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 39118 (\N{CJK UNIFIED IDEOGRAPH-98CE}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 38505 (\N{CJK UNIFIED IDEOGRAPH-9669}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 35780 (\N{CJK UNIFIED IDEOGRAPH-8BC4}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 25915 (\N{CJK UNIFIED IDEOGRAPH-653B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 20987 (\N{CJK UNIFIED IDEOGRAPH-51FB}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 31867 (\N{CJK UNIFIED IDEOGRAPH-7C7B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 22411 (\N{CJK UNIFIED IDEOGRAPH-578B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 27491 (\N{CJK UNIFIED IDEOGRAPH-6B63}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 24120 (\N{CJK UNIFIED IDEOGRAPH-5E38}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 35775 (\N{CJK UNIFIED IDEOGRAPH-8BBF}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 38382 (\N{CJK UNIFIED IDEOGRAPH-95EE}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 24405 (\N{CJK UNIFIED IDEOGRAPH-5F55}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 36941 (\N{CJK UNIFIED IDEOGRAPH-904D}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21382 (\N{CJK UNIFIED IDEOGRAPH-5386}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 36328 (\N{CJK UNIFIED IDEOGRAPH-8DE8}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 31449 (\N{CJK UNIFIED IDEOGRAPH-7AD9}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 33050 (\N{CJK UNIFIED IDEOGRAPH-811A}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21453 (\N{CJK UNIFIED IDEOGRAPH-53CD}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 24207 (\N{CJK UNIFIED IDEOGRAPH-5E8F}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21015 (\N{CJK UNIFIED IDEOGRAPH-5217}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 28431 (\N{CJK UNIFIED IDEOGRAPH-6F0F}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 27934 (\N{CJK UNIFIED IDEOGRAPH-6D1E}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21033 (\N{CJK UNIFIED IDEOGRAPH-5229}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 29992 (\N{CJK UNIFIED IDEOGRAPH-7528}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 27880 (\N{CJK UNIFIED IDEOGRAPH-6CE8}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 20837 (\N{CJK UNIFIED IDEOGRAPH-5165}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21253 (\N{CJK UNIFIED IDEOGRAPH-5305}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21547 (\N{CJK UNIFIED IDEOGRAPH-542B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 36828 (\N{CJK UNIFIED IDEOGRAPH-8FDC}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21629 (\N{CJK UNIFIED IDEOGRAPH-547D}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 20196 (\N{CJK UNIFIED IDEOGRAPH-4EE4}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 25191 (\N{CJK UNIFIED IDEOGRAPH-6267}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 20256 (\N{CJK UNIFIED IDEOGRAPH-4F20}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 26041 (\N{CJK UNIFIED IDEOGRAPH-65B9}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 27861 (\N{CJK UNIFIED IDEOGRAPH-6CD5}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21608 (\N{CJK UNIFIED IDEOGRAPH-5468}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 20108 (\N{CJK UNIFIED IDEOGRAPH-4E8C}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 19977 (\N{CJK UNIFIED IDEOGRAPH-4E09}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 22235 (\N{CJK UNIFIED IDEOGRAPH-56DB}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 20116 (\N{CJK UNIFIED IDEOGRAPH-4E94}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 20845 (\N{CJK UNIFIED IDEOGRAPH-516D}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 26143 (\N{CJK UNIFIED IDEOGRAPH-661F}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21578 (\N{CJK UNIFIED IDEOGRAPH-544A}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 35686 (\N{CJK UNIFIED IDEOGRAPH-8B66}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 23567 (\N{CJK UNIFIED IDEOGRAPH-5C0F}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 27169 (\N{CJK UNIFIED IDEOGRAPH-6A21}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 24335 (\N{CJK UNIFIED IDEOGRAPH-5F0F}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 21305 (\N{CJK UNIFIED IDEOGRAPH-5339}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 37197 (\N{CJK UNIFIED IDEOGRAPH-914D}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 32479 (\N{CJK UNIFIED IDEOGRAPH-7EDF}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 35745 (\N{CJK UNIFIED IDEOGRAPH-8BA1}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 35814 (\N{CJK UNIFIED IDEOGRAPH-8BE6}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 32454 (\N{CJK UNIFIED IDEOGRAPH-7EC6}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# /content/WuTong/src/wutong/report.py:196: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from font(s) DejaVu Sans.
#   plt.savefig(out_path, dpi=150, bbox_inches="tight")
# 2026-02-14 14:25:35,295 INFO 攻击分析图已保存: /content/WuTong/data/outputs/colab_test/attack_analysis.png
# 2026-02-14 14:25:35,329 INFO 文本报告已保存: /content/WuTong/data/outputs/colab_test/security_report.txt
# 2026-02-14 14:25:35,455 INFO CSV 报告已保存: /content/WuTong/data/outputs/colab_test/detailed_alert_report.csv  (11000 条)
# 2026-02-14 14:25:35,489 INFO === 推理任务完成: colab_test, 输出目录: /content/WuTong/data/outputs/colab_test ===
#
# ============================================================
# 推理完成!
# ============================================================
#   任务 ID:    colab_test
#   告警总数:   11,000
#   输出目录:   /content/WuTong/data/outputs/colab_test
#
#   风险摘要:
#     低危: 4128
#     信息: 3939
#     中危: 2933
#     avg_score: 25.0
#     max_score: 59.5
#
#   降噪统计:
#     original_count: 11000
#     cluster_count: 29
#     noise_count: 56
#     aggregated_count: 85
#     reduction_rate: 99.2
#
#   生成文件:
#     - security_dashboard.png
#     - attack_analysis.png
#     - security_report.txt
#     - detailed_alert_report.csv
#     - final_results.parquet
#
# ✅ 推理完成！
#
# 查看结果:
# total 2476
# drwxr-xr-x 2 root root    4096 Feb 14 14:25 .
# drwxr-xr-x 3 root root    4096 Feb 14 14:25 ..
# -rw-r--r-- 1 root root  137902 Feb 14 14:25 attack_analysis.png
# -rw-r--r-- 1 root root 1355442 Feb 14 14:25 detailed_alert_report.csv
# -rw-r--r-- 1 root root  761937 Feb 14 14:25 final_results.parquet
# -rw-r--r-- 1 root root  260357 Feb 14 14:25 security_dashboard.png
# -rw-r--r-- 1 root root    2385 Feb 14 14:25 security_report.txt

# %% [markdown]
# ---
#
# ## ✅ 训练完成！
#
# ### 📊 关键指标
#
# - **模型架构**: XGBoost + CatBoost + LightGBM 三模型集成
# - **预期准确率**: 98.5-99.5%
# - **训练方式**: 5 折交叉验证
# - **数据量**: 11,000 条告警数据
# - **攻击类型**: 9 类（8 种攻击 + 正常访问）
#
# ### 📦 已生成文件
#
# ```
# models/v2.0.0/
# ├── ensemble.pkl              # 集成模型（主要使用）
# ├── xgboost.pkl               # XGBoost 单模型
# ├── catboost.pkl              # CatBoost 单模型
# ├── lightgbm.pkl              # LightGBM 单模型
# ├── label_encoder.pkl         # 标签编码器
# ├── aggregator.pkl            # 告警聚合器
# ├── manifest.json             # 模型元数据
# ├── feature_list.json         # 特征列表
# └── classification_report.txt # 详细分类报告
# ```
#
# ### 🚀 下一步
#
# 1. ✅ 下载 `models_v2.0.0.zip` 到本地
# 2. ✅ 解压到项目的 `models/` 目录
# 3. ✅ 在本地 CPU 上运行推理（完全兼容）
# 4. ✅ 集成到 API 服务或 Electron 前端
#
# ### ❓ 常见问题
#
# **Q: Colab 训练的模型能在本地 CPU 运行吗？**
# A: 完全可以！模型训练时使用的是 CPU 指令，GPU 只是加速计算。下载后可以直接在任何 CPU 环境运行。
#
# **Q: 准确率没达到预期怎么办？**
# A: 可以尝试：
# - 增加交叉验证折数：`--cv-splits 10`
# - 调整模型超参数
# - 补充公开数据集
#
# **Q: 模型文件太大怎么办？**
# A: 只保留 `ensemble.pkl`、`label_encoder.pkl`、`aggregator.pkl` 和配置文件即可，单模型文件可以删除。
#
# ---
#
# **项目地址**: https://github.com/alltobebetter/WuTong
